# %%
from RNN_demo_lib import series_slider
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
predict_series = series_slider.MySeries()
predict_series.load_data('apple_prices.csv')    # load in a csv - remember no header!

# %%
# predict in future
predict_series.train_n_predict(test_periods = 100)

# %%
predict_series.my_slider()

# %%
predict_series.testing_predictions
# Out:
# [0.58703393,
#  0.55863112,
#  0.52515131,
#  0.50417536,
#  0.48324996,
#  0.46072328,
#  0.44209552,
#  0.42613602,
#  0.4143495,
#  0.40474999,
#  0.39733404,
#  0.39357734,
#  0.39243931,
#  0.39372981,
#  0.3972131,
#  0.40260273,
#  0.40984434,
#  0.41838354,
#  0.42790931,
#  0.43818885,
#  0.44887173,
#  0.45969051,
#  0.47034323,
#  0.48059237,
#  0.49024802,
#  0.49911195,
#  0.50704151,
#  0.51392645,
#  0.51969004,
#  0.5242933,
#  0.52772093,
#  0.52999192,
#  0.53115183,
#  0.53126705,
#  0.53042471,
#  0.52872652,
#  0.52628672,
#  0.52322781,
#  0.51967597,
#  0.51575887,
#  0.51160204,
#  0.50732589,
#  0.50304347,
#  0.49885833,
#  0.49486274,
#  0.49113643,
#  0.48774612,
#  0.48474443,
#  0.48217034,
#  0.48004919,
#  0.47839308,
#  0.47720206,
#  0.47646499,
#  0.47616071,
#  0.47625953,
#  0.47672457,
#  0.47751319,
#  0.47857887,
#  0.47987223,
#  0.48134261,
#  0.4829396,
#  0.4846139,
#  0.48631859,
#  0.48801023,
#  0.48964918,
#  0.49120051,
#  0.49263442,
#  0.49392653,
#  0.49505788,
#  0.49601507,
#  0.49678999,
#  0.49737954,
#  0.49778551,
#  0.49801373,
#  0.49807405,
#  0.49797934,
#  0.4977451,
#  0.49738902,
#  0.49693,
#  0.4963879,
#  0.49578291,
#  0.49513495,
#  0.49446321,
#  0.49378592,
#  0.49311984,
#  0.4924801,
#  0.4918797,
#  0.49132973,
#  0.49083924,
#  0.4904148,
#  0.49006099,
#  0.48978025,
#  0.48957312,
#  0.48943824,
#  0.48937267,
#  0.48937207,
#  0.4894309,
#  0.4895426,
#  0.48970002,
#  0.48989546]
